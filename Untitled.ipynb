# %%
import librosa
import math
import librosa.display as display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.mixture import GaussianMixture
import fastaudio.core.signal as fcs
import GetTranscription
lvpath ="E:\Datasets\Voice\Librivox\dev\LibriSpeech\dev-clean"
mcvpath ="E:\Datasets\Voice\Mozilla Common Voice\en\cv-corpus-6.1-2020-12-11\en"

clips =fcs.get_audio_files(lvpath)
# Out:
# C:\Users\nerdi\.conda\envs\pyAudio\lib\site-packages\torchaudio\extension\extension.py:13: UserWarning: torchaudio C++ extension is not available.
#   warnings.warn('torchaudio C++ extension is not available.')
# C:\Users\nerdi\.conda\envs\pyAudio\lib\site-packages\torchaudio\backend\utils.py:46: UserWarning: "torchaudio.USE_SOUNDFILE_LEGACY_INTERFACE" flag is deprecated and will be removed in 0.9.0. Please remove the use of flag.
#   warnings.warn(

# %%
clip= clips[45]
audio,sr = librosa.load(clip)
print(clip)
print(GetTranscription.get_file_transcript(clip))
print(audio.shape)
librosa.display.waveplot(audio,sr=sr,alpha=0.4)
ipd.Audio(audio[:],rate=sr)
# Out:
# E:\Datasets\Voice\Librivox\dev\LibriSpeech\dev-clean\1272\141231\1272-141231-0005.flac
# A MINUTE IS NOT A VERY LARGE MEASURE OF TIME AND HIS BODY NEEDED EVERY FRACTION OF IT
# (128111,)
# Exception ignored in: <function tqdm.__del__ at 0x00000207C9FE11F0>
# Traceback (most recent call last):
#   File "C:\Users\nerdi\.conda\envs\pyAudio\lib\site-packages\tqdm\std.py", line 1145, in __del__
#     self.close()
#   File "C:\Users\nerdi\.conda\envs\pyAudio\lib\site-packages\tqdm\notebook.py", line 275, in close
#     self.disp(bar_style='danger')
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x00000207C9FE11F0>
# Traceback (most recent call last):
#   File "C:\Users\nerdi\.conda\envs\pyAudio\lib\site-packages\tqdm\std.py", line 1145, in __del__
#     self.close()
#   File "C:\Users\nerdi\.conda\envs\pyAudio\lib\site-packages\tqdm\notebook.py", line 275, in close
#     self.disp(bar_style='danger')
# AttributeError: 'tqdm' object has no attribute 'disp'
# Exception ignored in: <function tqdm.__del__ at 0x00000207C9FE11F0>
# Traceback (most recent call last):
#   File "C:\Users\nerdi\.conda\envs\pyAudio\lib\site-packages\tqdm\std.py", line 1145, in __del__
#     self.close()
#   File "C:\Users\nerdi\.conda\envs\pyAudio\lib\site-packages\tqdm\notebook.py", line 275, in close
#     self.disp(bar_style='danger')
# AttributeError: 'tqdm' object has no attribute 'disp'
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def three_features(audio):
    energy =normalize(librosa.pcen(audio,sr=sr))
    #np.nan_to_num(energy, copy=False, nan=0.0, posinf=None, neginf=None)
    zcr = normalize(librosa.zero_crossings(energy))
    spectral_centroids = librosa.feature.spectral_centroid(audio, sr=sr)[0]
    acr = librosa.autocorrelate(spectral_centroids)
    return np.c_[energy,zcr,acr]

# %%
librosa.zero_crossings(audio).shape
# Out:
# (59205,)

# %%
librosa.pcen(audio,sr=sr).shape
# Out:
# C:\Users\nerdi\.conda\envs\pyAudio\lib\site-packages\librosa\core\spectrum.py:2210: RuntimeWarning: invalid value encountered in log1p
#   smooth = np.exp(-gain * (np.log(eps) + np.log1p(S_smooth / eps)))
# C:\Users\nerdi\.conda\envs\pyAudio\lib\site-packages\librosa\core\spectrum.py:2218: RuntimeWarning: invalid value encountered in log1p
#   S_out = (bias ** power) * np.expm1(power * np.log1p(S * smooth / bias))
# (59205,)

# %%
w_e= librosa.feature.spectral_bandwidth(audio+0.01, sr=sr)[0]

# %%
wo_e=librosa.feature.spectral_bandwidth(audio, sr=sr)[0]

# %%
wo_e.shape
# Out:
# (116,)

# %%
plt.plot(w_e)

# %%
print (w_e.shape)
print(audio.shape)
# Out:
# (116,)
# (128111,)

# %%
librosa.autocorrelate(wo_e).shape
# Out:
# (116,)

# %%
librosa.zero_crossings(audio).shape
# Out:
# (128111,)

# %%
librosa.pcen(audio).shape
# Out:
# (128111,)

# %%
librosa.display.waveplot(audio,sr=sr,alpha=0.4)

plt.plot(w_e)
plt.plot(wo_e)

# %%
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
tokenizer = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-64-3abfe883170e> in <module>
#       1 from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
# ----> 2 tokenizer = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
#       3 model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")
#
# ~\.conda\envs\pyAudio\lib\site-packages\transformers\models\wav2vec2\processing_wav2vec2.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     102                 :class:`~transformers.PreTrainedTokenizer`
#     103         """
# --> 104         feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained(pretrained_model_name_or_path, **kwargs)
#     105         tokenizer = Wav2Vec2CTCTokenizer.from_pretrained(pretrained_model_name_or_path, **kwargs)
#     106
#
# ~\.conda\envs\pyAudio\lib\site-packages\transformers\feature_extraction_utils.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     279             assert unused_kwargs == {'foo': False}
#     280         """
# --> 281         feature_extractor_dict, kwargs = cls.get_feature_extractor_dict(pretrained_model_name_or_path, **kwargs)
#     282
#     283         return cls.from_dict(feature_extractor_dict, **kwargs)
#
# ~\.conda\envs\pyAudio\lib\site-packages\transformers\feature_extraction_utils.py in get_feature_extractor_dict(cls, pretrained_model_name_or_path, **kwargs)
#     342         try:
#     343             # Load from URL or cache if already cached
# --> 344             resolved_feature_extractor_file = cached_path(
#     345                 feature_extractor_file,
#     346                 cache_dir=cache_dir,
#
# ~\.conda\envs\pyAudio\lib\site-packages\transformers\file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1163     if is_remote_url(url_or_filename):
#    1164         # URL, so get it from the cache (downloading if necessary)
# -> 1165         output_path = get_from_cache(
#    1166             url_or_filename,
#    1167             cache_dir=cache_dir,
#
# ~\.conda\envs\pyAudio\lib\site-packages\transformers\file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#    1426             logger.info(f"{url} not found in cache or force_download set to True, downloading to {temp_file.name}")
#    1427
# -> 1428             http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#    1429
#    1430         logger.info(f"storing {url} in cache at {cache_path}")
#
# ~\.conda\envs\pyAudio\lib\site-packages\transformers\file_utils.py in http_get(url, temp_file, proxies, resume_size, headers)
#    1277     content_length = r.headers.get("Content-Length")
#    1278     total = resume_size + int(content_length) if content_length is not None else None
# -> 1279     progress = tqdm(
#    1280         unit="B",
#    1281         unit_scale=True,
#
# ~\.conda\envs\pyAudio\lib\site-packages\tqdm\notebook.py in __init__(self, *args, **kwargs)
#     233         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     234         total = self.total * unit_scale if self.total else self.total
# --> 235         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     236         self.container.pbar = self
#     237         if display_here:
#
# ~\.conda\envs\pyAudio\lib\site-packages\tqdm\notebook.py in status_printer(_, total, desc, ncols)
#     110         # Prepare IPython progress bar
#     111         if IProgress is None:  # #187 #451 #558 #872
# --> 112             raise ImportError(
#     113                 "IProgress not found. Please update jupyter and ipywidgets."
#     114                 " See https://ipywidgets.readthedocs.io/en/stable"
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %%
input_values = tokenizer(audio, return_tensors = ["pt"]).input_values
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-63-91cb78d8b3c5> in <module>
# ----> 1 input_values = tokenizer(audio, return_tensors = ["pt"]).input_values
#
# ~\.conda\envs\pyAudio\lib\site-packages\transformers\tokenization_utils_base.py in __call__(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2208         """
#    2209         # Input type checking for clearer error
# -> 2210         assert isinstance(text, str) or (
#    2211             isinstance(text, (list, tuple))
#    2212             and (
#
# AssertionError: text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
